# %%
import os

# Define the directory where the files are located
directory = '/home/tappay01/data/water/DATASET'

# Iterate through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.npy'):
        # Split the filename into parts based on underscores
        parts = filename.split('_')
        
        # Check if the third part is '0' and replace it with '0.1'
        if len(parts) >= 3 and parts[2] == '0':
            parts[2] = '0.1'
            
            # Join the parts back together to form the new filename
            new_filename = '_'.join(parts)
            
            # Construct the full paths for the old and new filenames
            old_filepath = os.path.join(directory, filename)
            new_filepath = os.path.join(directory, new_filename)
            
            # Rename the file
            os.rename(old_filepath, new_filepath)
            print(f'Renamed: {filename} to {new_filename}')
# Out:
# Renamed: DATASET_2000MeV_0_-121.5.npy to DATASET_2000MeV_0.1_-121.5.npy
# Renamed: DATASET_1250MeV_0_-121.5.npy to DATASET_1250MeV_0.1_-121.5.npy
# Renamed: DATASET_2750MeV_0_-121.5.npy to DATASET_2750MeV_0.1_-121.5.npy
# Renamed: DATASET_2000MeV_0_-71.5.npy to DATASET_2000MeV_0.1_-71.5.npy
# Renamed: DATASET_1500MeV_0_-71.5.npy to DATASET_1500MeV_0.1_-71.5.npy
# Renamed: DATASET_1250MeV_0_-71.5.npy to DATASET_1250MeV_0.1_-71.5.npy
# Renamed: DATASET_1500MeV_0_-46.5.npy to DATASET_1500MeV_0.1_-46.5.npy
# Renamed: DATASET_1750MeV_0_-46.5.npy to DATASET_1750MeV_0.1_-46.5.npy
# Renamed: DATASET_1250MeV_0_-146.5.npy to DATASET_1250MeV_0.1_-146.5.npy
# Renamed: DATASET_2500MeV_0_-96.5.npy to DATASET_2500MeV_0.1_-96.5.npy
# Renamed: DATASET_2500MeV_0_-121.5.npy to DATASET_2500MeV_0.1_-121.5.npy
# Renamed: DATASET_2750MeV_0_-146.5.npy to DATASET_2750MeV_0.1_-146.5.npy
# Renamed: DATASET_2750MeV_0_-46.5.npy to DATASET_2750MeV_0.1_-46.5.npy
# Renamed: DATASET_2250MeV_0_-121.5.npy to DATASET_2250MeV_0.1_-121.5.npy
# Renamed: DATASET_1500MeV_0_-96.5.npy to DATASET_1500MeV_0.1_-96.5.npy
# Renamed: DATASET_2750MeV_0_-71.5.npy to DATASET_2750MeV_0.1_-71.5.npy
# Renamed: DATASET_1750MeV_0_-146.5.npy to DATASET_1750MeV_0.1_-146.5.npy
# Renamed: DATASET_1500MeV_0_-146.5.npy to DATASET_1500MeV_0.1_-146.5.npy
# Renamed: DATASET_2000MeV_0_-96.5.npy to DATASET_2000MeV_0.1_-96.5.npy
# Renamed: DATASET_2000MeV_0_-146.5.npy to DATASET_2000MeV_0.1_-146.5.npy
# Renamed: DATASET_1750MeV_0_-71.5.npy to DATASET_1750MeV_0.1_-71.5.npy
# Renamed: DATASET_1250MeV_0_-46.5.npy to DATASET_1250MeV_0.1_-46.5.npy
# Renamed: DATASET_1250MeV_0_-96.5.npy to DATASET_1250MeV_0.1_-96.5.npy
# Renamed: DATASET_2000MeV_0_-46.5.npy to DATASET_2000MeV_0.1_-46.5.npy
# Renamed: DATASET_1500MeV_0_-121.5.npy to DATASET_1500MeV_0.1_-121.5.npy
# Renamed: DATASET_2250MeV_0_-96.5.npy to DATASET_2250MeV_0.1_-96.5.npy
# Renamed: DATASET_2250MeV_0_-146.5.npy to DATASET_2250MeV_0.1_-146.5.npy
# Renamed: DATASET_2250MeV_0_-71.5.npy to DATASET_2250MeV_0.1_-71.5.npy
# Renamed: DATASET_2500MeV_0_-146.5.npy to DATASET_2500MeV_0.1_-146.5.npy
# Renamed: DATASET_2250MeV_0_-46.5.npy to DATASET_2250MeV_0.1_-46.5.npy
# Renamed: DATASET_2500MeV_0_-71.5.npy to DATASET_2500MeV_0.1_-71.5.npy
# Renamed: DATASET_1750MeV_0_-121.5.npy to DATASET_1750MeV_0.1_-121.5.npy
# Renamed: DATASET_1750MeV_0_-96.5.npy to DATASET_1750MeV_0.1_-96.5.npy
# Renamed: DATASET_2500MeV_0_-46.5.npy to DATASET_2500MeV_0.1_-46.5.npy
# Renamed: DATASET_2750MeV_0_-96.5.npy to DATASET_2750MeV_0.1_-96.5.npy
